# %%
from xgolib import XGO
import time
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact, widgets, Button, VBox, IntSlider

dog = XGO("xgolite")

# %%
while True:
    print('yaw',dog.read_yaw())
    print('roll',dog.read_roll())
    print('pitch',dog.read_pitch())
    time.sleep(1)
# Out:
# yaw -9.8
# roll -0.13
# pitch 0.17
# yaw -9.8
# roll -0.09
# pitch 0.2
# yaw -9.8
# roll 0.13
# pitch -0.07
# yaw -34.5
# roll -1.15
# pitch 1.3
# yaw -50.66
# roll -0.17
# pitch 0.9
# yaw 12.95
# roll 0.13
# pitch -0.18
# yaw 4.02
# roll 1.63
# pitch -0.14
# yaw -11.57
# roll 0.67
# pitch 0.52
# yaw -12.85
# roll 2.2
# pitch -27.74
# yaw -11.34
# roll 1.16
# pitch -1.22
# yaw -12.86
# roll 0.52
# pitch 18.03
# yaw -10.62
# roll -0.0
# pitch -0.06
# yaw -10.62
# roll 0.3
# pitch -0.21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 print('roll',dog.read_roll())
#       4 print('pitch',dog.read_pitch())
# ----> 5 time.sleep(1)
#
# KeyboardInterrupt:

# %%
from xgoedu import XGOEDU 
import time
#实例化edu
XGO_edu = XGOEDU()
# Out:
# Screen already initialized.

# %%
#写法1 way1
while True:
    XGO_edu.lcd_picture("my1.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my2.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my3.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my4.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my5.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my6.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my7.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my8.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my9.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my10.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my11.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my12.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my13.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my14.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my15.png")
    time.sleep(.2)
    XGO_edu.lcd_picture("my16.png")
    time.sleep(.2)
    
    
    #写法2 way2
    for i in range(1,9):
        XGO_edu.lcd_picture("cute"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,12):
        XGO_edu.lcd_picture("sleep"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,12):
        XGO_edu.lcd_picture("query"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,13):
        XGO_edu.lcd_picture("na"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,13):
        XGO_edu.lcd_picture("gri"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,12):
        XGO_edu.lcd_picture("love"+str(i)+".png")
        time.sleep(.2)
        
    for i in range(1,11):
        XGO_edu.lcd_picture("shame"+str(i)+".png")
        time.sleep(.2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 39
#      37 #写法2 way2
#      38 for i in range(1,9):
# ---> 39     XGO_edu.lcd_picture("cute"+str(i)+".png")
#      40     time.sleep(.2)
#      42 for i in range(1,12):
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/xgoedu/__init__.py:222, in XGOEDU.lcd_picture(self, filename, x, y)
#     220 def lcd_picture(self,filename,x=0,y=0):
#     221     path="/home/pi/xgoPictures/"
# --> 222     image = Image.open(path+filename)
#     223     self.splash.paste(image,(x,y))
#     224     self.display.ShowImage(self.splash)
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/PIL/Image.py:3469, in open(fp, mode, formats)
#    3466     filename = os.path.realpath(os.fspath(fp))
#    3468 if filename:
# -> 3469     fp = builtins.open(filename, "rb")
#    3470     exclusive_fp = True
#    3471 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/pi/xgoPictures/cute1.png'

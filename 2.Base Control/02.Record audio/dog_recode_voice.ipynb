# %%
#导入xgoedu  #Import xguodu
from xgoedu import XGOEDU 
#实例化edu  #Instantiate edu
XGO_edu = XGOEDU()
# Out:
# Screen already initialized.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 4
#       2 from xgoedu import XGOEDU
#       3 #实例化edu  #Instantiate edu
# ----> 4 XGO_edu = XGOEDU()
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/xgoedu/__init__.py:123, in XGOEDU.__init__(self)
#     121 self.agesexmark=None
#     122 self.camera_still=False
# --> 123 GPIO.setup(self.key1,GPIO.IN,GPIO.PUD_UP)
#     124 GPIO.setup(self.key2,GPIO.IN,GPIO.PUD_UP)
#     125 GPIO.setup(self.key3,GPIO.IN,GPIO.PUD_UP)
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/RPi/GPIO/__init__.py:696, in setup(chanlist, direction, pull_up_down, initial)
#     694     except lgpio.error:
#     695         pass
# --> 696     _check(lgpio.gpio_claim_input(_chip, gpio, {
#     697         PUD_OFF:  lgpio.SET_PULL_NONE,
#     698         PUD_DOWN: lgpio.SET_PULL_DOWN,
#     699         PUD_UP:   lgpio.SET_PULL_UP,
#     700     }[pull_up_down]))
#     701 elif direction == OUT:
#     702     _unset_alert(gpio)
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/lgpio.py:755, in gpio_claim_input(handle, gpio, lFlags)
#     735 def gpio_claim_input(handle, gpio, lFlags=0):
#     736    """
#     737    This claims a GPIO for input.
#     738
#    (...)    753    ...
#     754    """
# --> 755    return _u2i(_lgpio._gpio_claim_input(handle&0xffff, lFlags, gpio))
#
# File ~/RaspberryPi-CM5/xgovenv/lib/python3.11/site-packages/lgpio.py:458, in _u2i(status)
#     456 if v < 0:
#     457    if exceptions:
# --> 458       raise error(error_text(v))
#     459 return v
#
# error: 'GPIO busy'

# %%
#myrecord：会保存到/home/pi/xgoMusic的文件下  5:录制音频时长
#Myrecord: will be saved to a file in/home/pi/xgomusic 5: recording audio duration
XGO_edu.xgoAudioRecord(filename="myrecord",seconds=5)
# Out:
# sudo arecord -d 5 -f S32_LE -r 8000 -c 1 -t wav /home/pi/xgoMusic/myrecord.wav
# Recording WAVE '/home/pi/xgoMusic/myrecord.wav' : Signed 32 bit Little Endian, Rate 8000 Hz, Mono

# %%
del XGO_edu

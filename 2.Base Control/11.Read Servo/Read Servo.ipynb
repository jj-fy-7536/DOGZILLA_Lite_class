# %%
from xgolib import XGO
import time
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact, widgets, Button, VBox, IntSlider

dog = XGO("xgolite")

# %%
while True:
    print(dog.read_motor())
    time.sleep(1)
# Out:
# [4.82, 36.67, 1.06, 4.82, 37.29, 0.59, 3.88, 47.96, 0.82, 3.41, 46.71, 0.35, 0.25, 70.0, -85.0]
# [4.82, 36.67, 1.06, 4.82, 37.29, 0.59, 3.88, 47.96, 0.82, 3.41, 46.71, 0.35, 0.25, 70.0, -85.0]
# [4.82, 36.67, 1.06, 4.35, 37.29, 0.59, 3.88, 47.96, 0.82, 3.41, 46.71, 0.35, 0.25, 70.0, -85.0]
# [4.82, 36.67, 1.06, 4.35, 37.29, 0.59, 3.88, 47.96, 0.82, 3.41, 46.71, 0.35, 0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 4.35, 36.67, 0.35, 2.47, 47.96, 0.82, 3.41, 46.71, 0.59, 0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 4.35, 36.67, 0.59, 2.47, 47.96, 1.06, 3.41, 46.71, 0.35, 0.25, 70.0, -85.0]
# [4.35, 36.67, 1.06, 4.35, 37.29, 0.59, 2.0, 47.96, 1.06, 3.41, 46.71, 0.59, 0.25, 70.0, -85.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 while True:
#       2     print(dog.read_motor())
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:

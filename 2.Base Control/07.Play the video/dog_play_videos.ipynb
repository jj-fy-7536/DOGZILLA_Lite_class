# %%
#导入xgoedu #Import xguodu
from xgoedu import XGOEDU 
#实例化edu #Instantiate edu
XGO_edu = XGOEDU()
# Out:
# Screen already initialized.

# %%
#会播放到/home/pi/xgoVideos的文件下
#It will play to the file/home/pi/xgoVideos
XGO_edu.xgoVideo(filename="myvidoes.mp4")
# Out:
# /home/pi/xgoVideos/myvidoes.mp4
# 15.0
# MPlayer UNKNOWN-12 (C) 2000-2023 MPlayer Team
#
# Playing /home/pi/xgoVideos/myvidoes.mp4.
# libavformat version 59.27.100 (external)
# libavformat file format detected.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7ffec0f662d0]Protocol name not provided, cannot determine if input is local or a network protocol, buffers and access patterns cannot be configured optimally without knowing the protocol
# [lavf] stream 0: video (mpeg4), -vid 0
#
#
# Exiting... (End of file)
# do_connect: could not connect to socket
# connect: No such file or directory
# Failed to open LIRC support. You will not be able to use your remote control.
# No stream found.

# %%
XGO_edu.xgoCamera(False)   #关闭摄像头 #Turn off the camera
del XGO_edu
